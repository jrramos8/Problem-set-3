// %% [markdown]
// ## Stats 211 Problem set 2
//
// [Jovana Ramos]
//
// [Exploring Possible Independent and Dependent Variables in UCUES]
//
// [2/25/2020]

// %% [markdown]
// ### 1. Explain any new or revised hypotheses for interval ratio data from your own project or from Charlie's grant and loan repayment data
//
// [Your answer here should explain:
// 1. What are your dependent variables? Why do they interest you?
// My dependent variable is hours spent with family. This variable interest me because there might be students who spent too much time with their families instead of spending time studying.
//
// 2. What are your independent variables? What direction to you hypothesize will be the relationship between your dependent variable and your dependent variables?
// The independent variables being used below are whether or not students consider themselves Hispanic. Another of my independent variables is students’ cumulative GPAs. I selected these variables to decide if students who identity as Hispanic spent more time with their families versus students who do not identify as Hispanic.
// 3. Why do you think your dependent variables are associated with your independent variables?
// I think there is an association between my variables due to the literature. According to the literature most Latino students are family oriented and therefor may be pulled to go back home.
// 4. What are your control variables? Do you think they will show any spurious, intervening, or interactive relationships? Why?]
// Within the data I saw that there were students who spend more than 3 hours with their family, which I'm assuming these students live at home. Therefore, whether or not students moved away from home should be one of my control variables. I think there will be an interactive relationship between my variables.
// If you are working with the grant and loan repayment data, formulate hypotheses about:
// 1. The relationship between state grant aid per student and the level of research at a university
// 2. The relationship between loan repayment and college net price for low-income students. The later variable is name **netprice4lowincome**

// %% [markdown]
// ### 2. Setting up your session
//
// In the code cell below, do the following:
//
// 1. set current directory
// 2. set more off
// 3. create log file
// 4. download the data from its source if it's available online
// 5. read the data in [preferably only variables you are going to use]

// %%
clear

// %%
cd C:\Users\Jovis\Desktop\SOC_211
// Out:
// C:\Users\Jovis\Desktop\SOC_211

// %%
set more off

// %%
log using C:\Users\Jovis\Desktop\SOC_211\Assignment3.log, replace
// Out:
// (note: file C:\Users\Jovis\Desktop\SOC_211\Assignment3.log not found)
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//       name:  <unnamed>
//        log:  C:\Users\Jovis\Desktop\SOC_211\Assignment3.log
//   log type:  text
//  opened on:  25 Feb 2020, 19:42:34

// %%
use UCUES, clear

// %% [markdown]
// ### 3. Create a bar graph with confidence interval whiskers
//
// Create a bar graph that compares interval ratio data for a dependent variable across different nominal categories from an independent variable. If you are using Charlie's data, do this for the state grant aid per low income student variable name **sgrnt_low**

// %%
graph bar ructimefamily hispanic_1numeric
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// ### 4. Summarize what you learned from the bar graph
//
// Do the confidence intervals overlap across categories or not? What does this mean?

// %% [markdown]
// The above graph is displaying the number of hours a student is spending with their family. The graph is also displaying whether or not the student identified as Hispanic.

// %% [markdown]
// ### 4. Estimate OLS regression statistics for the relationship between two interval ratio variables and ouput the table below
//
// If you use Charlie's data, use the loan repayment variable and the **netprice4lowincome** variable.

// %%
regress ructimefamily CUMGPA_NATIVE
// Out:
//       Source |       SS           df       MS      Number of obs   =     1,185
// -------------+----------------------------------   F(1, 1183)      =      9.23
//        Model |  30.7112261         1  30.7112261   Prob > F        =    0.0024
//     Residual |  3936.92928     1,183  3.32791993   R-squared       =    0.0077
// -------------+----------------------------------   Adj R-squared   =    0.0069
//        Total |  3967.64051     1,184  3.35104772   Root MSE        =    1.8243
//
// -------------------------------------------------------------------------------
// ructimefamily |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// CUMGPA_NATIVE |  -.2534261   .0834236    -3.04   0.002    -.4171009   -.0897513
//         _cons |   3.098366   .2440474    12.70   0.000     2.619552     3.57718
// -------------------------------------------------------------------------------

// %% [markdown]
// ### 5. Interpret the output
//
// 1. What is the coefficient for your independent variable? What does it say about the size and direction of the relationship you estimated?
// The coefficient for my independent variable is -.253. The relationship that I estimated between the variables is negative.
//
// 2. What is the p-value for the coefficient for your independent variable? What does it indicate about how much confidence we can have in the estimated relationship?
// The p-value for the coefficient is 0. Meaning that I have enough confidence to reject the null hypothesis.
//
// 3. What is the $r^2$ coefficient of determination? What does it say about how much variation in your dependent variable is explained by the independent variable?
// The r^2 coefficient of determination is 0.0077. This means that 7.7% of the variation in GPA can be explained by variation in time spent with family.
//
// 4. What is the F-ratio for your $r^2$. What does it indicate about how much confidence we can have in the $r^2$ estimate?
// The F-ration for the r^2 is 9.23, which indicates that there is 9.23 level of confidence in the r^2 estimate.

// %% [markdown]
// ### 6. Illustrate the OLS relationship with a scatter plot that includes a fitted line

// %%
tw (scatter ructimefamily CUMGPA_NATIVE) ///
(lfit ructimefamily CUMGPA_NATIVE, color(red))
// Out:
// This front-end cannot display the desired image type.
